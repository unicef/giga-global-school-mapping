# %% [markdown]
# ## Imports and Setup

# %%
import os
import pandas as pd
import geopandas as gpd
import logging
import joblib
import torch

import sys
sys.path.insert(0, "../src")
import sat_download

sys.path.insert(0, "../utils/")
import post_utils
import config_utils
import data_utils

import matplotlib.pyplot as plt
from PIL import Image

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load Config Files

# %%
iso_code = "MOZ"
sum_threshold=5

cwd = os.path.dirname(os.getcwd())
data_config_file = os.path.join(cwd, "configs/data_config.yaml")
data_config = config_utils.load_config(data_config_file)

model_config_file = os.path.join(cwd, "configs/cnn_configs/convnext_small_v01.yaml")
model_config = config_utils.load_config(model_config_file)

# %% [markdown]
# ## Load Reference

# %%
#reference = post_utils.load_reference(iso_code, data_config, model_config, sum_threshold)
filename = os.path.join(cwd, data_config["vectors_dir"], data_config["pos_class"], "osm", "MOZ_osm.geojson")
reference = gpd.read_file(filename)
reference["geometry"] = reference.to_crs("EPSG:3857")["geometry"].centroid
reference.head(3)
# Out:
#                          giga_id_school  school_id  \
# 0  99f0bd85-d03f-4e16-85a5-ac6f66ff40e2  663190261
# 1  935ec5c1-d73a-48e5-ae8f-e652178be77b  757390569
# 2  f06b1135-0c3d-41ad-96bb-8c42cccb4476  903054787
#
#                           name        lat        lon education_level  \
# 0               primary school -19.642206  34.755461         Primary
# 1  Maputo International School -25.979337  32.588228         Unknown
# 2         SOS Children Village -23.883524  35.402704         Unknown
#
#   education_level_regional school_type school_type_govt connectivity  ...  \
# 0                  Primary        None             None         None  ...
# 1                  Unknown        None             None         None  ...
# 2                  Unknown        None             None         None  ...
#
#   nearest_LTE_distance nearest_UMTS_id nearest_UMTS_distance nearest_GSM_id  \
# 0                 None            None                  None           None
# 1                 None            None                  None           None
# 2                 None            None                  None           None
#
#   nearest_GSM_distance pop_within_1km pop_within_2km pop_within_3km  \
# 0                 None           None           None           None
# 1                 None           None           None           None
# 2                 None           None           None           None
#
#   pop_within_10km                          geometry
# 0            None  POINT (3868960.199 -2230693.125)
# 1            None  POINT (3627704.969 -2996522.005)
# 2            None  POINT (3941011.038 -2739221.460)
#
# [3 rows x 47 columns]

# %% [markdown]
# ## Load Master Dataset

# %%
master = post_utils.load_master(iso_code, data_config, name="unicef_clean")
master.head(3)
# Out:
# INFO:root:unicef_clean
# 0    11289
# 4     1511
# 2      220
# Name: count, dtype: int64
# INFO:root:Data dimensions: (13020, 10)
#                          MUID  source  iso     country  region  \
# 0  UNICEF-MOZ-SCHOOL-00000000  UNICEF  MOZ  Mozambique  Africa
# 1  UNICEF-MOZ-SCHOOL-00000001  UNICEF  MOZ  Mozambique  Africa
# 2  UNICEF-MOZ-SCHOOL-00000002  UNICEF  MOZ  Mozambique  Africa
#
#             subregion                                     name giga_id_school  \
# 0  Sub-Saharan Africa  Escola Primário do 1º Grau 4 de Outubro              0
# 1  Sub-Saharan Africa            Escola Primária de Naicuainha              1
# 2  Sub-Saharan Africa                Escola Primária de Lipapa              2
#
#    unicef_clean                    geometry
# 0             0  POINT (33.23836 -19.21253)
# 1             0  POINT (35.20014 -13.47617)
# 2             4  POINT (35.54036 -13.43500)

# %% [markdown]
# ## Get Distance between Reference and Master

# %%
temp = data_utils._convert_crs(master.copy(), target_crs="EPSG:3857") #.set_index("MUID")
dist = temp.geometry.apply(lambda x: reference.distance(x).sort_values())
master["distance"] = dist.min(axis=1).values
master.head(3)
# Out:
#                          MUID  source  iso     country  region  \
# 0  UNICEF-MOZ-SCHOOL-00000000  UNICEF  MOZ  Mozambique  Africa
# 1  UNICEF-MOZ-SCHOOL-00000001  UNICEF  MOZ  Mozambique  Africa
# 2  UNICEF-MOZ-SCHOOL-00000002  UNICEF  MOZ  Mozambique  Africa
#
#             subregion                                     name giga_id_school  \
# 0  Sub-Saharan Africa  Escola Primário do 1º Grau 4 de Outubro              0
# 1  Sub-Saharan Africa            Escola Primária de Naicuainha              1
# 2  Sub-Saharan Africa                Escola Primária de Lipapa              2
#
#    unicef_clean                    geometry      distance
# 0             0  POINT (33.23836 -19.21253)  21754.066006
# 1             0  POINT (35.20014 -13.47617)  20576.590400
# 2             4  POINT (35.54036 -13.43500)  35951.235519

# %% [markdown]
# ## Filter Master Dataset

# %%
master[(master.unicef_clean == 0) & (master["distance"] < 250)].shape
# Out:
# (394, 11)

# %%
result.to_file("SEN_results_centroid.geojson", driver="GeoJSON")

# %%
master.to_file("SEN_master.geojson", driver="GeoJSON")
