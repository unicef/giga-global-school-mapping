# %% [markdown]
# # Imports and Setup

# %%
import os
import pandas as pd
import geopandas as gpd
import logging

import sys
sys.path.insert(0, "../utils/")
import model_utils
import config_utils
import embed_utils
import data_utils
from foundation import Foundation

import torch
import torch.nn as nn
from tqdm import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # DINOv2 Embeddings

# %% [markdown]
# ## Data Configurations

# %%
iso_code = "KEN"
cwd = os.path.dirname(os.getcwd())
config_file = os.path.join(cwd, f"configs/dino_configs/dinov2_vits14-LR.yaml")
config = config_utils.load_config(config_file)
config["iso_codes"] = [iso_code]

data = model_utils.load_data(config, attributes=["rurban", "iso"], verbose=True)
data.head(3)
# Out:
# INFO:root:Data dimensions: 15222
# INFO:root:
#   rurban  iso       class  count  percentage
# 0  rural  KEN  non_school   2883    0.189397
# 1  rural  KEN      school   1432    0.094074
# 2  urban  KEN  non_school   7265    0.477270
# 3  urban  KEN      school   3642    0.239259
# INFO:root:
#                                count  percentage
# rurban iso class      dataset
# rural  KEN non_school test       276    0.181340
#                       train     2322         NaN
#                       val        285    0.187254
#            school     test       155    0.101840
#                       train     1147         NaN
#                       val        130    0.085414
# urban  KEN non_school test       737    0.484231
#                       train     5833         NaN
#                       val        695    0.456636
#            school     test       353    0.231932
#                       train     2941         NaN
#                       val        348    0.228647
# INFO:root:
#                     count  percentage
# dataset class
# test    non_school   1013    0.066548
#         school        508    0.033373
# train   non_school   8155    0.535738
#         school       4088    0.268559
# val     non_school    980    0.064381
#         school        478    0.031402
# INFO:root:
# dataset
# train    12243
# test      1521
# val       1458
# Name: count, dtype: int64
# INFO:root:
# dataset
# train    0.804296
# test     0.099921
# val      0.095782
# Name: proportion, dtype: float64
# INFO:root:
# rurban
# urban    10907
# rural     4315
# Name: count, dtype: int64
# INFO:root:
# rurban
# urban    0.716529
# rural    0.283471
# Name: proportion, dtype: float64
# INFO:root:
# class
# non_school    10148
# school         5074
# Name: count, dtype: int64
# INFO:root:
# class
# non_school    0.666667
# school        0.333333
# Name: proportion, dtype: float64
#                        UID source  iso country  region           subregion  \
# 0  OSM-KEN-SCHOOL-00000000    OSM  KEN   Kenya  Africa  Sub-Saharan Africa
# 4  OSM-KEN-SCHOOL-00000004    OSM  KEN   Kenya  Africa  Sub-Saharan Africa
# 5  OSM-KEN-SCHOOL-00000005    OSM  KEN   Kenya  Africa  Sub-Saharan Africa
#
#                              name giga_id_school  clean  validated  \
# 0             Kinderworld Academy           None      0        0.0
# 4          Rose of Sharon Academy           None      0        0.0
# 5  Pangani Girls Secondary School           None      0        0.0
#
#                           geometry   class  ghsl_smod rurban dataset
# 0  POINT (3689959.200 -162438.182)  school         30  urban   train
# 4  POINT (3686875.352 -160919.480)  school         30  urban   train
# 5  POINT (3691385.838 -156893.126)  school         30  urban   train

# %% [markdown]
# ## Load Model

# %%
model = torch.hub.load("facebookresearch/dinov2", config["embed_model"])
model.name = config["embed_model"]
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Using cache found in /home/itingzon.unicef/.cache/torch/hub/facebookresearch_dinov2_main
# /home/itingzon.unicef/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /home/itingzon.unicef/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /home/itingzon.unicef/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# INFO:dinov2:using MLP layer as FFN
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 384, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %% [markdown]
# ## Urban Schools

# %%
subdata = data[(data.rurban=="urban") & (data["class"] == "school")]
embed_utils.visualize_embeddings(config, subdata, model, batch_size=5)

# %%
subdata = data[(data.rurban=="urban") & (data["class"] == "non_school")]
embed_utils.visualize_embeddings(config, subdata, model, batch_size=5)

# %% [markdown]
# ## Rural Schools

# %%
subdata = data[(data.rurban=="rural") & (data["class"] == "school")]
embed_utils.visualize_embeddings(config, subdata, model, batch_size=5)

# %%
subdata = data[(data.rurban=="rural") & (data["class"] == "non_school")]
embed_utils.visualize_embeddings(config, subdata, model, batch_size=5)

# %% [markdown]
# ## Compute Embeddings

# %%
out_dir = os.path.join(config["vectors_dir"], "embeddings")
embeddings = embed_utils.get_image_embeddings(
    config, data, model, out_dir, in_dir=None, columns=["iso", "rurban", "dataset", "class"]
)
embeddings.head(3)
# Out:
# INFO:root:Reading file /home/itingzon.unicef/giga/data/vectors/embeddings/MNG_dinov2_vits14_embeds.csv
#                             UID         0         1         2         3  \
# 0  OVERTURE-MNG-SCHOOL-00000005 -2.888033 -0.108523  5.691371 -2.143276
# 1  OVERTURE-MNG-SCHOOL-00000006 -2.589591 -0.156911  5.571325 -4.166053
# 2  OVERTURE-MNG-SCHOOL-00000018 -2.531917  0.847107  3.817045 -2.197662
#
#           4         5         6         7         8  ...       378       379  \
# 0  0.669561 -2.958966 -2.102606  0.754148 -0.106829  ...  1.265511 -3.531531
# 1  0.541174 -0.911260 -2.040312 -0.669896 -1.048705  ...  1.132965 -1.922010
# 2  2.105122 -0.644953 -2.360759  0.050235  1.632953  ...  2.703199 -2.559021
#
#         380       381       382       383  iso  rurban  dataset   class
# 0 -0.315876  1.205464 -2.272689  3.702338  MNG   urban    train  school
# 1  1.084568  2.454362 -5.554929  3.728537  MNG   urban    train  school
# 2 -0.785523  0.349606 -3.324399  4.424771  MNG   urban    train  school
#
# [3 rows x 389 columns]

# %% [markdown]
# # ESA Foundation Model Embeddings

# %% [markdown]
# ## Model Configs

# %%
iso_code = "BWA"
cwd = os.path.dirname(os.getcwd())
config_file = os.path.join(cwd, f"configs/model_configs/esa_foundation-LR.yaml")
config = config_utils.load_config(config_file)
config["iso_codes"] = [iso_code]

data = model_utils.load_data(config, attributes=["rurban", "iso"], verbose=False)
data.head(3)
# Out:
#                             UID    source  iso   country  region  \
# 0  OVERTURE-BWA-SCHOOL-00000000  OVERTURE  BWA  Botswana  Africa
# 1  OVERTURE-BWA-SCHOOL-00000001  OVERTURE  BWA  Botswana  Africa
# 2  OVERTURE-BWA-SCHOOL-00000003  OVERTURE  BWA  Botswana  Africa
#
#             subregion                         name giga_id_school  clean  \
# 0  Sub-Saharan Africa        Serule Primary School           None      0
# 1  Sub-Saharan Africa          Kang Primary School           None      0
# 2  Sub-Saharan Africa  Gantsi Senior School Ground           None      0
#
#    validated   class  ghsl_smod rurban dataset  \
# 0        0.0  school         13  rural   train
# 1        0.0  school         23  urban   train
# 2        0.0  school         23  urban   train
#
#                            geometry
# 0  POINT (2612095.427 -2684825.662)
# 1  POINT (2163196.151 -2894439.869)
# 2  POINT (2072772.072 -2658792.498)

# %% [markdown]
# ## Load Model

# %%
model_file = os.path.join(cwd, f"models/foundation_local_v03_e011.pt")
model = Foundation(
    input_dim=config["input_dim"],
    depths=config["depths"], 
    dims=config["dims"],
    img_size=config["image_size"],
    latent_dim=config["latent_dim"],
    dropout=config["dropout"],
    activation=nn.ReLU6(),
)
model.name = config["embed_model"]
model.load_state_dict(torch.load(model_file, map_location=device), strict=False)
model.eval();

# %% [markdown]
# ## Compute Embeddings

# %%
image_files = data_utils.get_image_filepaths(config, data)
out_dir = os.path.join(config["vectors_dir"], "embeddings")
embeddings = embed_utils.get_image_embeddings(
    config, data, model, out_dir, columns=["iso", "rurban", "dataset", "class"]
)
embeddings.head(3)
# Out:
# 100%|████████████████████| 2606/2606 [8:04:05<00:00, 11.15s/it]
# INFO:root:Saved to /home/itingzon.unicef/giga/data/vectors/embeddings/BWA_esa_foundation_embeds.csv
#                                      0         1         2         3  \
# UID
# OVERTURE-BWA-SCHOOL-00000000  1.292681 -0.423336  0.580245 -1.329876
# OVERTURE-BWA-SCHOOL-00000001  0.761518 -0.303446  0.549824 -1.317577
# OVERTURE-BWA-SCHOOL-00000003  1.003423 -0.233891  0.364701 -1.095844
#
#                                      4         5         6         7  \
# UID
# OVERTURE-BWA-SCHOOL-00000000 -1.086299 -0.238224 -0.605698  0.669051
# OVERTURE-BWA-SCHOOL-00000001 -1.619856  0.438902 -0.861322  0.867736
# OVERTURE-BWA-SCHOOL-00000003 -1.526610  0.093927 -0.672186  0.570617
#
#                                      8         9  ...      1018      1019  \
# UID                                               ...
# OVERTURE-BWA-SCHOOL-00000000 -0.156950  0.031464  ... -1.082415 -0.739226
# OVERTURE-BWA-SCHOOL-00000001  0.428994 -0.188972  ... -0.994569 -0.436137
# OVERTURE-BWA-SCHOOL-00000003  0.162825  0.060725  ... -0.743859 -0.411639
#
#                                   1020      1021      1022      1023  iso  \
# UID
# OVERTURE-BWA-SCHOOL-00000000  0.737304 -0.580990 -0.540339 -1.312907  BWA
# OVERTURE-BWA-SCHOOL-00000001  0.894621 -0.735322 -0.212001 -0.993920  BWA
# OVERTURE-BWA-SCHOOL-00000003  0.754309 -0.616263 -0.295198 -1.178626  BWA
#
#                               rurban  dataset   class
# UID
# OVERTURE-BWA-SCHOOL-00000000   rural    train  school
# OVERTURE-BWA-SCHOOL-00000001   urban    train  school
# OVERTURE-BWA-SCHOOL-00000003   urban    train  school
#
# [3 rows x 1028 columns]
